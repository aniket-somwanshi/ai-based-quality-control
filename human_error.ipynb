# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
import numpy as np

import json

# %%
df = pd.read_csv('/content/drive/MyDrive/r3_inframind/datasets/human_error.csv')

# %%
df.head()
# Out:
#    inspector_experience_months  ...  inspection_error
# 0                           22  ...                 1
# 1                           24  ...                 1
# 2                           26  ...                 1
# 3                           28  ...                 1
# 4                           30  ...                 1
#
# [5 rows x 6 columns]

# %%
df.columns
# Out:
# Index(['inspector_experience_months', 'production_line_age', 'is_night_shift',
#        'is_break_due', 'erros_per_batch', 'inspection_error'],
#       dtype='object')

# %%
df = df.dropna()

# %%
df.head()
# Out:
#    inspector_experience_months  ...  inspection_error
# 0                           22  ...                 1
# 1                           24  ...                 1
# 2                           26  ...                 1
# 3                           28  ...                 1
# 4                           30  ...                 1
#
# [5 rows x 6 columns]

# %%
df.head()
# Out:
#    inspector_experience_months  ...  inspection_error
# 0                           22  ...                 1
# 1                           24  ...                 1
# 2                           26  ...                 1
# 3                           28  ...                 1
# 4                           30  ...                 1
#
# [5 rows x 6 columns]

# %%
df.describe()
# Out:
#        inspector_experience_months  ...  inspection_error
# count                    47.000000  ...         47.000000
# mean                     27.936170  ...          0.638298
# std                      12.251716  ...          0.485688
# min                       1.000000  ...          0.000000
# 25%                      24.000000  ...          0.000000
# 50%                      32.000000  ...          1.000000
# 75%                      37.000000  ...          1.000000
# max                      42.000000  ...          1.000000
#
# [8 rows x 6 columns]

# %%
df.columns
# Out:
# Index(['inspector_experience_months', 'production_line_age', 'is_night_shift',
#        'is_break_due', 'erros_per_batch', 'inspection_error'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['inspector_experience_months', 'production_line_age', 'is_night_shift',
#        'is_break_due', 'erros_per_batch', 'inspection_error'],
#       dtype='object')

# %%
# Randomize rows
df = df.sample(frac=1).reset_index(drop=True)

# %%
len(df.index)
# Out:
# 47

# %%
# check NULL values
# np.any(np.isnan(df))
# np.isfinite(data.all()) #and gets True

# %%
df.head()
# Out:
#    inspector_experience_months  ...  inspection_error
# 0                           38  ...                 1
# 1                           22  ...                 1
# 2                           24  ...                 1
# 3                           28  ...                 0
# 4                           42  ...                 0
#
# [5 rows x 6 columns]

# %%
# train test split by specifying row number to split at
def train_test_split(data, pred_feature_name, row_to_split_at):  
  y = data[pred_feature_name].copy()
  x = data.drop(pred_feature_name, axis=1).copy()
  
  y_train = y.iloc[:row_to_split_at] #indexes rows for test data
  X_train = x.iloc[:row_to_split_at] #indexes rows for training data

  X_test = x.iloc[row_to_split_at:] #indexes rows for training data
  y_test = y.iloc[row_to_split_at:] #indexes rows for test data

  return X_train, X_test, y_train, y_test

# %%
# split
X_train, X_test, y_train, y_test = train_test_split(df,'inspection_error', 25)

# %%
X_train
# Out:
#     inspector_experience_months  ...  erros_per_batch
# 0                            38  ...               20
# 1                            22  ...               31
# 2                            24  ...               21
# 3                            28  ...               23
# 4                            42  ...               30
# 5                            30  ...               24
# 6                            22  ...               20
# 7                            26  ...               33
# 8                             1  ...               23
# 9                            32  ...               36
# 10                           40  ...               29
# 11                            3  ...               25
# 12                           32  ...               25
# 13                            7  ...               29
# 14                           36  ...               25
# 15                           40  ...               29
# 16                           28  ...               34
# 17                           42  ...               30
# 18                           40  ...               21
# 19                           40  ...               27
# 20                           24  ...               32
# 21                           36  ...               27
# 22                           36  ...               27
# 23                           24  ...               21
# 24                           30  ...               35
#
# [25 rows x 5 columns]

# %%
X_test
# Out:
#     inspector_experience_months  ...  erros_per_batch
# 25                            6  ...               28
# 26                           22  ...               20
# 27                           32  ...               25
# 28                            7  ...               29
# 29                           34  ...               37
# 30                           32  ...               23
# 31                            4  ...               26
# 32                           26  ...               22
# 33                           36  ...               38
# 34                           38  ...               28
# 35                           38  ...               26
# 36                           34  ...               26
# 37                           34  ...               26
# 38                           30  ...               24
# 39                           42  ...               22
# 40                           38  ...               28
# 41                            5  ...               27
# 42                            2  ...               24
# 43                           28  ...               23
# 44                           42  ...               28
# 45                           26  ...               22
# 46                           34  ...               24
#
# [22 rows x 5 columns]

# %%
# # FOR CLASSIFICATION PROBLEM,
# # IF dataset is imbalanced
# from imblearn.over_sampling import SMOTE
# from imblearn.over_sampling import RandomOverSampler
# smote = RandomOverSampler( sampling_strategy=0.5)
# # 0.5 means minority = majority/2
# X_train, y_train = smote.fit_sample(X_train, y_train)

# %%
X_train
# Out:
#     inspector_experience_months  ...  erros_per_batch
# 0                            38  ...               20
# 1                            22  ...               31
# 2                            24  ...               21
# 3                            28  ...               23
# 4                            42  ...               30
# 5                            30  ...               24
# 6                            22  ...               20
# 7                            26  ...               33
# 8                             1  ...               23
# 9                            32  ...               36
# 10                           40  ...               29
# 11                            3  ...               25
# 12                           32  ...               25
# 13                            7  ...               29
# 14                           36  ...               25
# 15                           40  ...               29
# 16                           28  ...               34
# 17                           42  ...               30
# 18                           40  ...               21
# 19                           40  ...               27
# 20                           24  ...               32
# 21                           36  ...               27
# 22                           36  ...               27
# 23                           24  ...               21
# 24                           30  ...               35
#
# [25 rows x 5 columns]

# %%
X_test
# Out:
#     inspector_experience_months  ...  erros_per_batch
# 25                            6  ...               28
# 26                           22  ...               20
# 27                           32  ...               25
# 28                            7  ...               29
# 29                           34  ...               37
# 30                           32  ...               23
# 31                            4  ...               26
# 32                           26  ...               22
# 33                           36  ...               38
# 34                           38  ...               28
# 35                           38  ...               26
# 36                           34  ...               26
# 37                           34  ...               26
# 38                           30  ...               24
# 39                           42  ...               22
# 40                           38  ...               28
# 41                            5  ...               27
# 42                            2  ...               24
# 43                           28  ...               23
# 44                           42  ...               28
# 45                           26  ...               22
# 46                           34  ...               24
#
# [22 rows x 5 columns]

# %%
type(X_train), type(X_test), type(y_train) ,type(y_test)
# Out:
# (pandas.core.frame.DataFrame,
#  pandas.core.frame.DataFrame,
#  pandas.core.series.Series,
#  pandas.core.series.Series)

# %%
# import evaluation metrices
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

# %%
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier, ExtraTreesClassifier, VotingClassifier
import xgboost as xgb
from sklearn.metrics import accuracy_score, f1_score,confusion_matrix,classification_report
from sklearn.svm import SVC

# %%
clf = ExtraTreesClassifier(random_state=0,n_estimators=100)
clf.fit(X_train, y_train)
y_pred= clf.predict(X_test)
print('ExtraTreesClassifier accuracy: {}'.format(accuracy_score(y_test, y_pred)))
print(f'The accuracy score: {accuracy_score(y_test, y_pred)}')
print(f'The F1 Score is: {f1_score(y_test,y_pred)}')
print(classification_report(y_test, y_pred))
# Out:
# ExtraTreesClassifier accuracy: 0.8181818181818182
# The accuracy score: 0.8181818181818182
# The F1 Score is: 0.8333333333333333
#               precision    recall  f1-score   support
#
#            0       0.73      0.89      0.80         9
#            1       0.91      0.77      0.83        13
#
#     accuracy                           0.82        22
#    macro avg       0.82      0.83      0.82        22
# weighted avg       0.83      0.82      0.82        22

# %%
clf3 = AdaBoostClassifier(n_estimators=100)
clf3.fit(X_train, y_train)
y_pred= clf3.predict(X_test)
print('AdaBoostClassifier accuracy: {}'.format(accuracy_score(y_test, y_pred)))
print(f'The accuracy score: {accuracy_score(y_test, y_pred)}')
print(f'The F1 Score is: {f1_score(y_test,y_pred)}')
print(classification_report(y_test, y_pred))
# Out:
# AdaBoostClassifier accuracy: 0.9090909090909091
# The accuracy score: 0.9090909090909091
# The F1 Score is: 0.9166666666666666
#               precision    recall  f1-score   support
#
#            0       0.82      1.00      0.90         9
#            1       1.00      0.85      0.92        13
#
#     accuracy                           0.91        22
#    macro avg       0.91      0.92      0.91        22
# weighted avg       0.93      0.91      0.91        22

# %%
clf = GradientBoostingClassifier(random_state=0)
clf.fit(X_train, y_train)
y_pred= clf.predict(X_test)
print('GradientBoostingClassifier accuracy: {}'.format(accuracy_score(y_test, y_pred)))
print(f'The accuracy score: {accuracy_score(y_test, y_pred)}')
print(f'The F1 Score is: {f1_score(y_test,y_pred)}')
print(classification_report(y_test, y_pred))
# Out:
# GradientBoostingClassifier accuracy: 0.7727272727272727
# The accuracy score: 0.7727272727272727
# The F1 Score is: 0.8148148148148148
#               precision    recall  f1-score   support
#
#            0       0.75      0.67      0.71         9
#            1       0.79      0.85      0.81        13
#
#     accuracy                           0.77        22
#    macro avg       0.77      0.76      0.76        22
# weighted avg       0.77      0.77      0.77        22

# %%
from sklearn.linear_model import LogisticRegression

logreg = LogisticRegression()
logreg.fit(X_train, y_train)

train_pred = logreg.predict(X_train)
logreg_pred = logreg.predict(X_test)

print('Accuracy of Logistic regression classifier on TRAINING set: {:.2f}'
     .format(logreg.score(X_train, y_train)))
print(classification_report(y_train, train_pred))

print('Accuracy of Logistic regression classifier on TEST set: {:.2f}'
     .format(logreg.score(X_test, y_test)))
print(classification_report(y_test, logreg_pred))
# Out:
# Accuracy of Logistic regression classifier on TRAINING set: 0.84
#               precision    recall  f1-score   support
#
#            0       0.83      0.62      0.71         8
#            1       0.84      0.94      0.89        17
#
#     accuracy                           0.84        25
#    macro avg       0.84      0.78      0.80        25
# weighted avg       0.84      0.84      0.83        25
#
# Accuracy of Logistic regression classifier on TEST set: 0.64
#               precision    recall  f1-score   support
#
#            0       0.56      0.56      0.56         9
#            1       0.69      0.69      0.69        13
#
#     accuracy                           0.64        22
#    macro avg       0.62      0.62      0.62        22
# weighted avg       0.64      0.64      0.64        22

# %%
print(y_test.value_counts())
# print(type(logreg_pred))
print(pd.Series(logreg_pred).value_counts())
# Out:
# 1    13
# 0     9
# Name: inspection_error, dtype: int64
# 1    13
# 0     9
# dtype: int64

# %%
from sklearn.tree import DecisionTreeClassifier

clf = DecisionTreeClassifier().fit(X_train, y_train)

print('Accuracy of Decision Tree classifier on training set: {:.2f}'
     .format(clf.score(X_train, y_train)))
print('Accuracy of Decision Tree classifier on test set: {:.2f}'
     .format(clf.score(X_test, y_test)))

clf_pred = clf.predict(X_test)
print(classification_report(y_test, clf_pred))
# Out:
# Accuracy of Decision Tree classifier on training set: 1.00
# Accuracy of Decision Tree classifier on test set: 0.86
#               precision    recall  f1-score   support
#
#            0       0.75      1.00      0.86         9
#            1       1.00      0.77      0.87        13
#
#     accuracy                           0.86        22
#    macro avg       0.88      0.88      0.86        22
# weighted avg       0.90      0.86      0.86        22

# %%
clf2 = DecisionTreeClassifier(max_depth=12).fit(X_train, y_train)
print('Accuracy of Decision Tree classifier on training set: {:.2f}'
     .format(clf2.score(X_train, y_train)))
print('Accuracy of Decision Tree classifier on test set: {:.2f}'
     .format(clf2.score(X_test, y_test)))

clf_pred2 = (clf2.predict_proba(X_test)[:,1] >= 0.5).astype(bool) # set threshold as 0.3
# clf_pred2 = clf2.predict(X_test)
print(classification_report(y_test, clf_pred2))
# Out:
# Accuracy of Decision Tree classifier on training set: 1.00
# Accuracy of Decision Tree classifier on test set: 0.86
#               precision    recall  f1-score   support
#
#            0       0.75      1.00      0.86         9
#            1       1.00      0.77      0.87        13
#
#     accuracy                           0.86        22
#    macro avg       0.88      0.88      0.86        22
# weighted avg       0.90      0.86      0.86        22

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators=200, max_depth=30, random_state=0)
rf.fit(X_train, y_train)
# TRAIN SET EVAL
print('Accuracy of Random forest classifier on training set: {:.2f}'
     .format(rf.score(X_train, y_train)))
print(classification_report(y_train, train_pred))

# TEST SET EVAL
print('Accuracy of Random forest classifier on test set: {:.2f}'
     .format(rf.score(X_test, y_test)))

# rf_pred = rf.predict(X_test)
rf_pred = (rf.predict_proba(X_test)[:,1] >= 0.5).astype(bool) # set threshold as 0.3
train_pred = rf.predict(X_train)

print(classification_report(y_test, rf_pred))
# Out:
# Accuracy of Random forest classifier on training set: 1.00
#               precision    recall  f1-score   support
#
#            0       0.83      0.62      0.71         8
#            1       0.84      0.94      0.89        17
#
#     accuracy                           0.84        25
#    macro avg       0.84      0.78      0.80        25
# weighted avg       0.84      0.84      0.83        25
#
# Accuracy of Random forest classifier on test set: 0.77
#               precision    recall  f1-score   support
#
#            0       0.75      0.67      0.71         9
#            1       0.79      0.85      0.81        13
#
#     accuracy                           0.77        22
#    macro avg       0.77      0.76      0.76        22
# weighted avg       0.77      0.77      0.77        22

# %%
# SAVE THE MODEL
import pickle
pkl_filename = '/content/drive/MyDrive/r3_inframind/models/human_error.pkl'
with open(pkl_filename, 'wb') as file:
    pickle.dump(rf, file)
